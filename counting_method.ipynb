# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from itertools import product
import time
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
# !pip install kmodes

df = pd.read_csv('DATA/Truck_drivers_final.csv')
# Out:
# Requirement already satisfied: kmodes in c:\users\mique\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\mique\anaconda3\lib\site-packages (from kmodes) (1.19.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\mique\anaconda3\lib\site-packages (from kmodes) (0.23.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\mique\anaconda3\lib\site-packages (from kmodes) (1.5.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\mique\anaconda3\lib\site-packages (from kmodes) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mique\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->kmodes) (2.1.0)

# %%
categorical = ['deviation', 'seniority_in_the_job_months', 'age', 'time_day', 'time_workday', 'specific_physical_activity', 'injured_body_part', 'injury_description']
import pandas as pd
import itertools 

#Create a list of diferent combinations of 3 variables of the given variables in categorical with k=3.
combinations = list(itertools.combinations(categorical, 3))

# Load the dataset into a Pandas DataFrame

#Create a dictonary that has the results for each combination of variables

dic={}

# Count the number of occurrences of each unique combination of values
for combination in combinations:
    counts = data_sampled.groupby(list(combination)).size().reset_index(name='count')
    counts['percentage %'] = counts['count'] / data_sampled.shape[0] * 100

    # Get the top 10 combinations of values that are the most repeated in the dataset
    top_counts = counts.sort_values('count', ascending=False).head(10)
    dic[tuple(combination)]=counts.sort_values('count', ascending=False)
dic3=dic
# It gives the combinations of values that are frequent in more that 10 percent of all the accidents.
for key, value in dic.items():
    condition = value.iloc[:, -1] > 8
    result = value[condition]
    
    if not result.empty:
        print(result)
        print('-----------------------------------------------------')
# Out:
#                                             deviation  \
# 14  Movement of the body as a result of or with ph...
#
#    seniority_in_the_job_months                 time_workday  count  \
# 14                 Experienced  Worked between 3 to 6 hours      3
#
#     percentage %
# 14          10.0
# -----------------------------------------------------
#                                             deviation  \
# 22  Movement of the body without added physical ef...
#
#    seniority_in_the_job_months                 injury_description  count  \
# 22                 Experienced  Dislocations, sprains and strains      3
#
#     percentage %
# 22          10.0
# -----------------------------------------------------
#                                             deviation    age  \
# 21  Movement of the body without added physical ef...  36-45
# 7             Falling persons – Slip or trip and fall  46-55
#
#                 time_workday  count  percentage %
# 21  Worked more than 6 hours      3          10.0
# 7   Recently started working      3          10.0
# -----------------------------------------------------
#                                  deviation    age injured_body_part  count  \
# 8  Falling persons – Slip or trip and fall  46-55    Superior limbs      3
#
#    percentage %
# 8          10.0
# -----------------------------------------------------
#                                             deviation    age  \
# 21  Movement of the body without added physical ef...  36-45
#
#                    injury_description  count  percentage %
# 21  Dislocations, sprains and strains      4     13.333333
# -----------------------------------------------------
#                                  deviation              time_workday  \
# 4  Falling persons – Slip or trip and fall  Recently started working
#
#   injured_body_part  count  percentage %
# 4    Superior limbs      3          10.0
# -----------------------------------------------------
#                                             deviation  \
# 21  Movement of the body without added physical ef...
# 4             Falling persons – Slip or trip and fall
#
#                 time_workday                 injury_description  count  \
# 21  Worked more than 6 hours  Dislocations, sprains and strains      3
# 4   Recently started working    Wounds and superficial injuries      3
#
#     percentage %
# 21          10.0
# 4           10.0
# -----------------------------------------------------
#    seniority_in_the_job_months  age                 time_workday  count  \
# 0                  Experienced  +56  Worked between 3 to 6 hours      3
# 16                    Veterans  +56     Worked more than 6 hours      3
#
#     percentage %
# 0           10.0
# 16          10.0
# -----------------------------------------------------
#   seniority_in_the_job_months                 time_workday  \
# 1                 Experienced  Worked between 3 to 6 hours
#
#   specific_physical_activity  count  percentage %
# 1      Manual transportation      4     13.333333
# -----------------------------------------------------
#   seniority_in_the_job_months                 time_workday  \
# 1                 Experienced  Worked between 3 to 6 hours
#
#                                    injured_body_part  count  percentage %
# 1  Back, including spine and thoracolumbar vertebrae      3          10.0
# -----------------------------------------------------
#    seniority_in_the_job_months                 time_workday  \
# 1                  Experienced  Worked between 3 to 6 hours
# 15                    Veterans     Recently started working
#
#                    injury_description  count  percentage %
# 1   Dislocations, sprains and strains      5     16.666667
# 15    Wounds and superficial injuries      3     10.000000
# -----------------------------------------------------
#    seniority_in_the_job_months specific_physical_activity  \
# 2                  Experienced      Manual transportation
# 19                    Veterans      Manual transportation
#
#                    injury_description  count  percentage %
# 2   Dislocations, sprains and strains      3          10.0
# 19    Wounds and superficial injuries      3          10.0
# -----------------------------------------------------
#       age              time_workday  \
# 14  46-55  Recently started working
#
#                            specific_physical_activity  count  percentage %
# 14  Driving/being on board a means of transport or...      3          10.0
# -----------------------------------------------------
#       age                 time_workday injured_body_part  count  percentage %
# 21  46-55  Worked between 3 to 6 hours    Superior limbs      3          10.0
# 18  46-55     Recently started working    Superior limbs      3          10.0
# -----------------------------------------------------
#       age              time_workday                 injury_description  count  \
# 16  46-55  Recently started working    Wounds and superficial injuries      4
# 12  36-45  Worked more than 6 hours  Dislocations, sprains and strains      3
#
#     percentage %
# 16     13.333333
# 12     10.000000
# -----------------------------------------------------
#       age                         specific_physical_activity  \
# 17  46-55  Driving/being on board a means of transport or...
# 11  36-45                                           Movement
#
#                    injury_description  count  percentage %
# 17    Wounds and superficial injuries      3          10.0
# 11  Dislocations, sprains and strains      3          10.0
# -----------------------------------------------------
#       age injured_body_part injury_description  count  percentage %
# 19  46-55    Superior limbs     Bone fractures      3          10.0
# -----------------------------------------------------
#                    time_workday specific_physical_activity injured_body_part  \
# 12  Worked between 3 to 6 hours        Object manipulation    Superior limbs
#
#     count  percentage %
# 12      4     13.333333
# -----------------------------------------------------
#                   time_workday specific_physical_activity  \
# 6  Worked between 3 to 6 hours      Manual transportation
#
#                   injury_description  count  percentage %
# 6  Dislocations, sprains and strains      3          10.0
# -----------------------------------------------------
#                    time_workday injured_body_part  \
# 11  Worked between 3 to 6 hours    Superior limbs
# 15     Worked more than 6 hours    Inferior limbs
#
#                    injury_description  count  percentage %
# 11  Dislocations, sprains and strains      3          10.0
# 15  Dislocations, sprains and strains      3          10.0
# -----------------------------------------------------

# %%
import pandas as pd
import itertools 

#Create a list of diferent combinations of 4 variables of the given variables in categorical. K=4
combinations = list(itertools.combinations(categorical, 4))

# Load the dataset into a Pandas DataFrame

#Create a dictonary of the top 10 counts for each combination

dic={}

# Count the number of occurrences of each unique combination of values
for combination in combinations:
    counts = df.groupby(list(combination)).size().reset_index(name='count')
    counts['percentage %'] = counts['count'] / df.shape[0] * 100

    # Get the top 10 combinations of values that are the most repeated in the dataset
    top_counts = counts.sort_values('count', ascending=False).head(10)
    dic[tuple(combination)]=counts.sort_values('count', ascending=False)
dic4=dic 
# It gives the combinations of 4 values that are freqüent in more that 5 percent of all the accidents.
for key, value in dic.items():
    condition = value.iloc[:, -1] > 5
    result = value[condition]
    
    if not result.empty:
        print(result)
        print('-----------------------------------------------------')
# Out:
#                     time_workday specific_physical_activity injured_body_part  \
# 701  Worked between 3 to 6 hours                   Movement    Inferior limbs
#
#                     injury_description  count  percentage %
# 701  Dislocations, sprains and strains   9838      5.066094
# -----------------------------------------------------
